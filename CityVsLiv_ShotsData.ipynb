# %%
#import modules and packages
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

# %%
#scrape the single game shots
base_url = "https://understat.com/match/"
match = str(input("Please input the match ID: "))
url = base_url + match
# Out:
# Please input the match ID: 16690

# %%
url
# Out:
# 'https://understat.com/match/16690'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content,"lxml")
scripts = soup.find_all("script")

# %%
scripts
# Out:
# [<script>
#  			var THEME = localStorage.getItem("theme") || 'DARK';
#  			document.body.className = "theme-" + THEME.toLowerCase();
#  		</script>,
#  <script>
#  	var shotsData 	= JSON.parse('\x7B\x22h\x22\x3A\x5B\x7B\x22id\x22\x3A\x22467480\x22,\x22minute\x22\x3A\x224\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.894000015258789\x22,\x22Y\x22\x3A\x220.534000015258789\x22,\x22xG\x22\x3A\x220.40620744228363037\x22,\x22player\x22\x3A\x22Raheem\x20Sterling\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x22618\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2216690\x22,\x22h_team\x22\x3A\x22Manchester\x20City\x22,\x22a_team\x22\x3A\x22Liverpool\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D04\x2D10\x2015\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Gabriel\x20Jesus\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22467481\x22,\x22minute\x22\x3A\x224\x22,\x22result\x22\x3A\x22Goal\x22,\x22X\x22\x3A\x220.775\x22,\x22Y\x22\x3A\x220.654000015258789\x22,\x22xG\x22\x3A\x220.021575164049863815\x22,\x22player\x22\x3A\x22Kevin\x20De\x20Bruyne\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x22447\x22,\x22situation\x22\x3A\x22SetPiece\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22LeftFoot\x22,\x22match_id\x22\x3A\x2216690\x22,\x22h_team\x22\x3A\x22Manchester\x20City\x22,\x22a_team\x22\x3A\x22Liverpool\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D04\x2D10\x2015\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Bernardo\x20Silva\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22467483\x22,\x22minute\x22\x3A\x2215\x22,\x22result\x22\x3A\x22SavedShot\x22,\x22X\x22\x3A\x220.8390000152587891\x22,\x22Y\x22\x3A\x220.35700000762939454\x22,\x22xG\x22\x3A\x220.04631851240992546\x22,\x22player\x22\x3A\x22Gabriel\x20Jesus\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x225543\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2216690\x22,\x22h_team\x22\x3A\x22Manchester\x20City\x22,\x22a_team\x22\x3A\x22Liverpool\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D04\x2D10\x2015\x3A30\x3A00\x22,\x22player_assisted\x22\x3A\x22Raheem\x20Sterling\x22,\x22lastAction\x22\x3A\x22Pass\x22\x7D,\x7B\x22id\x22\x3A\x22467484\x22,\x22minute\x22\x3A\x2220\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.7569999694824219\x22,\x22Y\x22\x3A\x220.669000015258789\x22,\x22xG\x22\x3A\x220.015018761157989502\x22,\x22player\x22\x3A\x22Rodri\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x222496\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2216690\x22,\x22h_team\x22\x3A\x22Manchester\x20City\x22,\x22a_team\x22\x3A\x22Liverpool\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D04\x2D10\x2015\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22None\x22\x7D,\x7B\x22id\x22\x3A\x22467486\x22,\x22minute\x22\x3A\x2228\x22,\x22result\x22\x3A\x22MissedShots\x22,\x22X\x22\x3A\x220.899000015258789\x22,\x22Y\x22\x3A\x220.649000015258789\x22,\x22xG\x22\x3A\x220.06316415220499039\x22,\x22player\x22\x3A\x22Kevin\x20De\x20Bruyne\x22,\x22h_a\x22\x3A\x22h\x22,\x22player_id\x22\x3A\x22447\x22,\x22situation\x22\x3A\x22OpenPlay\x22,\x22season\x22\x3A\x222021\x22,\x22shotType\x22\x3A\x22RightFoot\x22,\x22match_id\x22\x3A\x2216690\x22,\x22h_team\x22\x3A\x22Manchester\x20City\x22,\x22a_team\x22\x3A\x22Liverpool\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22date\x22\x3A\x222022\x2D04\x2D10\x2015\x3A30\x3A00\x22,\x22player_assisted\x22\x3Anull,\x22lastAction\x22\x3A\x22None\x22\x7D,\x7B\x22id\x22\x3A\x22467487\x22,\x22minute\x22\x3A\x2234\x22,\x22result\x22\x3A\x22BlockedShot\x22,\x22X\x22\x3A\x220.87\x22,\x22Y\x22\x3A\x220.7340000152587891\x22,\x22xG\x22\x3A\x220.0344398058950901\x22,\x22player\x22\x3A\x22Jo\x5Cu00e3o\x20Ca ...
#  		match_info 	= JSON.parse('\x7B\x22id\x22\x3A\x2216690\x22,\x22fid\x22\x3A\x221549853\x22,\x22h\x22\x3A\x2288\x22,\x22a\x22\x3A\x2287\x22,\x22date\x22\x3A\x222022\x2D04\x2D10\x2015\x3A30\x3A00\x22,\x22league_id\x22\x3A\x221\x22,\x22season\x22\x3A\x222021\x22,\x22h_goals\x22\x3A\x222\x22,\x22a_goals\x22\x3A\x222\x22,\x22team_h\x22\x3A\x22Manchester\x20City\x22,\x22team_a\x22\x3A\x22Liverpool\x22,\x22h_xg\x22\x3A\x221.34647\x22,\x22a_xg\x22\x3A\x221.29983\x22,\x22h_w\x22\x3A\x220.3523\x22,\x22h_d\x22\x3A\x220.2984\x22,\x22h_l\x22\x3A\x220.3493\x22,\x22league\x22\x3A\x22EPL\x22,\x22h_shot\x22\x3A\x2211\x22,\x22a_shot\x22\x3A\x226\x22,\x22h_shotOnTarget\x22\x3A\x225\x22,\x22a_shotOnTarget\x22\x3A\x224\x22,\x22h_deep\x22\x3A\x227\x22,\x22a_deep\x22\x3A\x227\x22,\x22a_ppda\x22\x3A\x2218.8500\x22,\x22h_ppda\x22\x3A\x2216.6250\x22\x7D');
#  </script>,
#  <script>
#  	var rostersData	= JSON.parse('\x7B\x22h\x22\x3A\x7B\x22525510\x22\x3A\x7B\x22id\x22\x3A\x22525510\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x226054\x22,\x22team_id\x22\x3A\x2288\x22,\x22position\x22\x3A\x22GK\x22,\x22player\x22\x3A\x22Ederson\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.0344398058950901\x22,\x22xGBuildup\x22\x3A\x220.0344398058950901\x22,\x22positionOrder\x22\x3A\x221\x22\x7D,\x22525511\x22\x3A\x7B\x22id\x22\x3A\x22525511\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x22638\x22,\x22team_id\x22\x3A\x2288\x22,\x22position\x22\x3A\x22DR\x22,\x22player\x22\x3A\x22Kyle\x20Walker\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.7482401728630066\x22,\x22xGBuildup\x22\x3A\x220.7482401728630066\x22,\x22positionOrder\x22\x3A\x222\x22\x7D,\x22525512\x22\x3A\x7B\x22id\x22\x3A\x22525512\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x222498\x22,\x22team_id\x22\x3A\x2288\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22Aymeric\x20Laporte\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.08075831830501556\x22,\x22xGBuildup\x22\x3A\x220.08075831830501556\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22525513\x22\x3A\x7B\x22id\x22\x3A\x22525513\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x220\x22,\x22xG\x22\x3A\x220\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x22586\x22,\x22team_id\x22\x3A\x2288\x22,\x22position\x22\x3A\x22DC\x22,\x22player\x22\x3A\x22John\x20Stones\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x220\x22,\x22assists\x22\x3A\x220\x22,\x22xA\x22\x3A\x220\x22,\x22xGChain\x22\x3A\x220.08075831830501556\x22,\x22xGBuildup\x22\x3A\x220.08075831830501556\x22,\x22positionOrder\x22\x3A\x223\x22\x7D,\x22525514\x22\x3A\x7B\x22id\x22\x3A\x22525514\x22,\x22goals\x22\x3A\x220\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x221\x22,\x22xG\x22\x3A\x220.0344398058950901\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x222379\x22,\x22team_id\x22\x3A\x2288\x22,\x22position\x22\x3A\x22DL\x22,\x22player\x22\x3A\x22Jo\x5Cu00e3o\x20Cancelo\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roster_in\x22\x3A\x220\x22,\x22roster_out\x22\x3A\x220\x22,\x22key_passes\x22\x3A\x222\x22,\x22assists\x22\x3A\x221\x22,\x22xA\x22\x3A\x220.5682922601699829\x22,\x22xGChain\x22\x3A\x220.25646182894706726\x22,\x22xGBuildup\x22\x3A\x220.04631851240992546\x22,\x22positionOrder\x22\x3A\x224\x22\x7D,\x22525515\x22\x3A\x7B\x22id\x22\x3A\x22525515\x22,\x22goals\x22\x3A\x221\x22,\x22own_goals\x22\x3A\x220\x22,\x22shots\x22\x3A\x222\x22,\x22xG\x22\x3A\x220.0847393125295639\x22,\x22time\x22\x3A\x2290\x22,\x22player_id\x22\x3A\x22447\x22,\x22team_id\x22\x3A\x2288\x22,\x22position\x22\x3A\x22MC\x22,\x22player\x22\x3A\x22Kevin\x20De\x20Bruyne\x22,\x22h_a\x22\x3A\x22h\x22,\x22yellow_card\x22\x3A\x220\x22,\x22red_card\x22\x3A\x220\x22,\x22roste ...
#  </script>,
#  <script defer="" src="//ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js" type="text/javascript"></script>,
#  <script src="//ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript"></script>,
#  <script>
#  		WebFont.load({
#  			google: {
#  				families: ['Barlow:500', 'Anton']
#  			},
#  			active: function(){
#  				flagFontsLoading = true;
#  			}
#  		});
#  		var BASE_URL = 'https://understat.com/',
#  			PROMOTION =  JSON.parse('\x7B\x22id\x22\x3A\x227\x22,\x22name\x22\x3A\x22adsense\x22,\x22template\x22\x3A\x22\x3Cins\x20class\x3D\x5C\x22adsbygoogle\x5C\x22\x20style\x3D\x5C\x22display\x3Ablock\x5C\x22\x20data\x2Dad\x2Dclient\x3D\x5C\x22ca\x2Dpub\x2D7470116180195095\x5C\x22\x20data\x2Dad\x2Dslot\x3D\x5C\x222199699885\x5C\x22\x20data\x2Dad\x2Dformat\x3D\x5C\x22auto\x5C\x22\x20data\x2Dfull\x2Dwidth\x2Dresponsive\x3D\x5C\x22true\x5C\x22\x3E\x3C\x5C\x2Fins\x3E\x22,\x22js\x22\x3A\x22\x28adsbygoogle\x20\x3D\x20window.adsbygoogle\x20\x7C\x7C\x20\x5B\x5D\x29.push\x28\x7B\x7D\x29\x3B\x22,\x22countries_list_type\x22\x3A\x22black\x22,\x22clicks\x22\x3A\x223891\x22\x7D') ;
#  	</script>,
#  <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>,
#  <script defer="" src="//code.jquery.com/jquery-1.12.4.js" type="text/javascript"></script>,
#  <script defer="" src="//code.jquery.com/ui/1.12.1/jquery-ui.js" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.iframetracker.min.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="//cdnjs.cloudflare.com/ajax/libs/Chart.js/2.7.2/Chart.min.js" type="text/javascript"></script>,
#  <script defer="" src="js/timsort.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/tooltip.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/pagination.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/select.js?v=2.1" type="text/javascript"></script>,
#  <script defer="" src="js/jquery.mousewheel.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/modernizr.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/simplebar.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/typeahead.bundle.js?v=2" type="text/javascript"></script>,
#  <script defer="" src="js/jTable.js?v=2.6" type="text/javascript"></script>,
#  <script defer="" src="js/main.js?v=2.9" type="text/javascript"></script>,
#  <script>
#  		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#  		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#  		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#  		})(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#  		ga('create', 'UA-101482034-1', 'auto');
#  		ga('send', 'pageview');
#
#  					window.onload = function() { (adsbygoogle = window.adsbygoogle || []).push({}); }
#  			</script>,
#  <script defer="" src="js/match.js?v=2.1" type="text/javascript"></script>]

# %%
#get only shots data
strings = scripts[1].string

# %%
strings
# Out:
# "\n\tvar shotsData \t= JSON.parse('\\x7B\\x22h\\x22\\x3A\\x5B\\x7B\\x22id\\x22\\x3A\\x22467480\\x22,\\x22minute\\x22\\x3A\\x224\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.894000015258789\\x22,\\x22Y\\x22\\x3A\\x220.534000015258789\\x22,\\x22xG\\x22\\x3A\\x220.40620744228363037\\x22,\\x22player\\x22\\x3A\\x22Raheem\\x20Sterling\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22618\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216690\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Liverpool\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D04\\x2D10\\x2015\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Gabriel\\x20Jesus\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22467481\\x22,\\x22minute\\x22\\x3A\\x224\\x22,\\x22result\\x22\\x3A\\x22Goal\\x22,\\x22X\\x22\\x3A\\x220.775\\x22,\\x22Y\\x22\\x3A\\x220.654000015258789\\x22,\\x22xG\\x22\\x3A\\x220.021575164049863815\\x22,\\x22player\\x22\\x3A\\x22Kevin\\x20De\\x20Bruyne\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22447\\x22,\\x22situation\\x22\\x3A\\x22SetPiece\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22LeftFoot\\x22,\\x22match_id\\x22\\x3A\\x2216690\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Liverpool\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D04\\x2D10\\x2015\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Bernardo\\x20Silva\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22467483\\x22,\\x22minute\\x22\\x3A\\x2215\\x22,\\x22result\\x22\\x3A\\x22SavedShot\\x22,\\x22X\\x22\\x3A\\x220.8390000152587891\\x22,\\x22Y\\x22\\x3A\\x220.35700000762939454\\x22,\\x22xG\\x22\\x3A\\x220.04631851240992546\\x22,\\x22player\\x22\\x3A\\x22Gabriel\\x20Jesus\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x225543\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216690\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Liverpool\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D04\\x2D10\\x2015\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3A\\x22Raheem\\x20Sterling\\x22,\\x22lastAction\\x22\\x3A\\x22Pass\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22467484\\x22,\\x22minute\\x22\\x3A\\x2220\\x22,\\x22result\\x22\\x3A\\x22BlockedShot\\x22,\\x22X\\x22\\x3A\\x220.7569999694824219\\x22,\\x22Y\\x22\\x3A\\x220.669000015258789\\x22,\\x22xG\\x22\\x3A\\x220.015018761157989502\\x22,\\x22player\\x22\\x3A\\x22Rodri\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x222496\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216690\\x22,\\x22h_team\\x22\\x3A\\x22Manchester\\x20City\\x22,\\x22a_team\\x22\\x3A\\x22Liverpool\\x22,\\x22h_goals\\x22\\x3A\\x222\\x22,\\x22a_goals\\x22\\x3A\\x222\\x22,\\x22date\\x22\\x3A\\x222022\\x2D04\\x2D10\\x2015\\x3A30\\x3A00\\x22,\\x22player_assisted\\x22\\x3Anull,\\x22lastAction\\x22\\x3A\\x22None\\x22\\x7D,\\x7B\\x22id\\x22\\x3A\\x22467486\\x22,\\x22minute\\x22\\x3A\\x2228\\x22,\\x22result\\x22\\x3A\\x22MissedShots\\x22,\\x22X\\x22\\x3A\\x220.899000015258789\\x22,\\x22Y\\x22\\x3A\\x220.649000015258789\\x22,\\x22xG\\x22\\x3A\\x220.06316415220499039\\x22,\\x22player\\x22\\x3A\\x22Kevin\\x20De\\x20Bruyne\\x22,\\x22h_a\\x22\\x3A\\x22h\\x22,\\x22player_id\\x22\\x3A\\x22447\\x22,\\x22situation\\x22\\x3A\\x22OpenPlay\\x22,\\x22season\\x22\\x3A\\x222021\\x22,\\x22shotType\\x22\\x3A\\x22RightFoot\\x22,\\x22match_id\\x22\\x3A\\x2216690\\x22,\\ ...

# %%
#strip symbols so we only get the json data
ind_start = strings.index("('") +2
ind_end = strings.index("')")

json_data = strings[ind_start:ind_end]
json_data = json_data.encode("utf8").decode("unicode_escape")

#convert string to json format
data = json.loads(json_data)

# %%
data
# Out:
# {'h': [{'id': '467480',
#    'minute': '4',
#    'result': 'SavedShot',
#    'X': '0.894000015258789',
#    'Y': '0.534000015258789',
#    'xG': '0.40620744228363037',
#    'player': 'Raheem Sterling',
#    'h_a': 'h',
#    'player_id': '618',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Gabriel Jesus',
#    'lastAction': 'Pass'},
#   {'id': '467481',
#    'minute': '4',
#    'result': 'Goal',
#    'X': '0.775',
#    'Y': '0.654000015258789',
#    'xG': '0.021575164049863815',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'SetPiece',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Pass'},
#   {'id': '467483',
#    'minute': '15',
#    'result': 'SavedShot',
#    'X': '0.8390000152587891',
#    'Y': '0.35700000762939454',
#    'xG': '0.04631851240992546',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Raheem Sterling',
#    'lastAction': 'Pass'},
#   {'id': '467484',
#    'minute': '20',
#    'result': 'BlockedShot',
#    'X': '0.7569999694824219',
#    'Y': '0.669000015258789',
#    'xG': '0.015018761157989502',
#    'player': 'Rodri',
#    'h_a': 'h',
#    'player_id': '2496',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '467486',
#    'minute': '28',
#    'result': 'MissedShots',
#    'X': '0.899000015258789',
#    'Y': '0.649000015258789',
#    'xG': '0.06316415220499039',
#    'player': 'Kevin De Bruyne',
#    'h_a': 'h',
#    'player_id': '447',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'None'},
#   {'id': '467487',
#    'minute': '34',
#    'result': 'BlockedShot',
#    'X': '0.87',
#    'Y': '0.7340000152587891',
#    'xG': '0.0344398058950901',
#    'player': 'João Cancelo',
#    'h_a': 'h',
#    'player_id': '2379',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Bernardo Silva',
#    'lastAction': 'Chipped'},
#   {'id': '467488',
#    'minute': '36',
#    'result': 'Goal',
#    'X': '0.9440000152587891',
#    'Y': '0.4370000076293945',
#    'xG': '0.39258870482444763',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'Cross'},
#   {'id': '467491',
#    'minute': '60',
#    'result': 'BlockedShot',
#    'X': '0.905',
#    'Y': '0.395',
#    'xG': '0.1757035255432129',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'João Cancelo',
#    'lastAction': 'TakeOn'},
#   {'id': '467493',
#    'minute': '71',
#    'result': 'MissedShots',
#    'X': '0.9369999694824219',
#    'Y': '0.28100000381469725',
#    'xG': '0.04596256837248802',
#    'player': 'Gabriel Jesus',
#    'h_a': 'h',
#    'player_id': '5543',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Pass'},
#   {'id': '467495',
#    'minute': '89',
#    'result': 'ShotOnPost',
#    'X': '0.7430000305175781',
#    'Y': '0.49900001525878906',
#    'xG': '0.059924039989709854',
#    'player': 'Riyad Mahrez',
#    'h_a': 'h',
#    'player_id': '750',
#    'situation': 'DirectFreekick',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'Standard'},
#   {'id': '467496',
#    'minute': '93',
#    'result': 'MissedShots',
#    'X': '0.8180000305175781',
#    'Y': '0.47900001525878905',
#    'xG': '0.08557088673114777',
#    'player': 'Riyad Mahrez',
#    'h_a': 'h',
#    'player_id': '750',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Kevin De Bruyne',
#    'lastAction': 'Pass'}],
#  'a': [{'id': '467482',
#    'minute': '12',
#    'result': 'Goal',
#    'X': '0.925',
#    'Y': '0.455',
#    'xG': '0.4858452081680298',
#    'player': 'Diogo Jota',
#    'h_a': 'a',
#    'player_id': '6854',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Trent Alexander-Arnold',
#    'lastAction': 'Pass'},
#   {'id': '467485',
#    'minute': '28',
#    'result': 'SavedShot',
#    'X': '0.48',
#    'Y': '0.46799999237060547',
#    'xG': '0.012577703222632408',
#    'player': 'Trent Alexander-Arnold',
#    'h_a': 'a',
#    'player_id': '1791',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Pass'},
#   {'id': '467489',
#    'minute': '45',
#    'result': 'Goal',
#    'X': '0.865',
#    'Y': '0.539000015258789',
#    'xG': '0.3536287844181061',
#    'player': 'Sadio Mané',
#    'h_a': 'a',
#    'player_id': '838',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'RightFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Throughball'},
#   {'id': '467490',
#    'minute': '51',
#    'result': 'SavedShot',
#    'X': '0.885',
#    'Y': '0.41900001525878905',
#    'xG': '0.3717997074127197',
#    'player': 'Diogo Jota',
#    'h_a': 'a',
#    'player_id': '6854',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Mohamed Salah',
#    'lastAction': 'Throughball'},
#   {'id': '467492',
#    'minute': '70',
#    'result': 'MissedShots',
#    'X': '0.8719999694824219',
#    'Y': '0.33599998474121096',
#    'xG': '0.059948183596134186',
#    'player': 'Mohamed Salah',
#    'h_a': 'a',
#    'player_id': '1250',
#    'situation': 'OpenPlay',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': 'Sadio Mané',
#    'lastAction': 'Pass'},
#   {'id': '467494',
#    'minute': '76',
#    'result': 'MissedShots',
#    'X': '0.7830000305175782',
#    'Y': '0.54',
#    'xG': '0.01603080704808235',
#    'player': 'Jordan Henderson',
#    'h_a': 'a',
#    'player_id': '605',
#    'situation': 'FromCorner',
#    'season': '2021',
#    'shotType': 'LeftFoot',
#    'match_id': '16690',
#    'h_team': 'Manchester City',
#    'a_team': 'Liverpool',
#    'h_goals': '2',
#    'a_goals': '2',
#    'date': '2022-04-10 15:30:00',
#    'player_assisted': None,
#    'lastAction': 'Aerial'}]}

# %%
x = []
y = []
xg = []
team = []
data_home = data["h"]
data_away = data["a"]

for index in range(len(data_home)):
    for key in data_home[index]:
        if key == "X":
            x.append(data_home[index][key])
        if key == "Y":
            y.append(data_home[index][key])
        if key == "xG":
            xg.append(data_home[index][key])
        if key == "h_team":
            team.append(data_home[index][key])
            
for index in range(len(data_away)):
    for key in data_away[index]:
        if key == "X":
            x.append(data_away[index][key])
        if key == "Y":
            y.append(data_away[index][key])
        if key == "xG":
            xg.append(data_away[index][key])
        if key == "a_team":
            team.append(data_away[index][key])

# %%
#create the dataframe
col_names = ["x", "y", "xg", "team"]
df = pd.DataFrame([x, y, xg, team], index=col_names)
df = df.T

# %%
df
# Out:
#                      x                    y                    xg  \
# 0    0.894000015258789    0.534000015258789   0.40620744228363037
# 1                0.775    0.654000015258789  0.021575164049863815
# 2   0.8390000152587891  0.35700000762939454   0.04631851240992546
# 3   0.7569999694824219    0.669000015258789  0.015018761157989502
# 4    0.899000015258789    0.649000015258789   0.06316415220499039
# 5                 0.87   0.7340000152587891    0.0344398058950901
# 6   0.9440000152587891   0.4370000076293945   0.39258870482444763
# 7                0.905                0.395    0.1757035255432129
# 8   0.9369999694824219  0.28100000381469725   0.04596256837248802
# 9   0.7430000305175781  0.49900001525878906  0.059924039989709854
# 10  0.8180000305175781  0.47900001525878905   0.08557088673114777
# 11               0.925                0.455    0.4858452081680298
# 12                0.48  0.46799999237060547  0.012577703222632408
# 13               0.865    0.539000015258789    0.3536287844181061
# 14               0.885  0.41900001525878905    0.3717997074127197
# 15  0.8719999694824219  0.33599998474121096  0.059948183596134186
# 16  0.7830000305175782                 0.54   0.01603080704808235
#
#                team
# 0   Manchester City
# 1   Manchester City
# 2   Manchester City
# 3   Manchester City
# 4   Manchester City
# 5   Manchester City
# 6   Manchester City
# 7   Manchester City
# 8   Manchester City
# 9   Manchester City
# 10  Manchester City
# 11        Liverpool
# 12        Liverpool
# 13        Liverpool
# 14        Liverpool
# 15        Liverpool
# 16        Liverpool
